# %% [markdown]
# # Summary

# %% [markdown]
# # Imports

# %%
# %run _imports.ipynb
# Out:
# Setting the PYTHON_VERSION environment variable.
# Setting the SPARK_MASTER environment variable.
# Setting the DB_TYPE environment variable.
# Setting the DB_PORT environment variable.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2017-11-23 13:41:13.874015

# %%
import zipfile

# %% [markdown]
# # Parameters

# %%
DATA_DIR = Path('../downloads/pmc/suppl/')

# %% [markdown]
# # Run

# %%
list(DATA_DIR.iterdir())
# Out:
# [PosixPath('../downloads/pmc/suppl/NON-OA'),
#  PosixPath('../downloads/pmc/suppl/OA')]

# %%
zfile = zipfile.ZipFile(DATA_DIR.joinpath('OA', 'PMC1085900-PMC1089899', 'PMC1088961.zip'))

# %%
csv_extensions = ['.csv', '.csv.gz', '.tsv', '.tsv.gz']
csv_files = []

xml_extensions = ['.xls', '.xls.gz', '.xlsx', '.xlsx.gz']
xml_files = []

for file in zfile.filelist:
    if any(file.filename.endswith(e) for e in csv_extensions):
        csv_files.append(file.filename)
    elif any(file.filename.endswith(e) for e in xml_extensions):
        xml_files.append(file.filename)

# %%
csv_files
# Out:
# []

# %%
x = {'a': 10, 'b': 20}
x.pop('a')
# Out:
# 10

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.sort_values(list(df.columns), axis=0)
# Out:
#     0  1  2
# 10  a  b  c
# 11  d  e  f

# %%
p = Path('.').absolute()

# %%
list(p.parents)[0]
# Out:
# PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables')

# %%
p.name
# Out:
# 'notebooks'

# %%
list(p.absolute().glob('*'))
# Out:
# [PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/_imports.ipynb'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/process_pmc_supl.ipynb'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/.ipynb_checkpoints'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/load_xml_files.ipynb'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/downloaded_pdfs'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/download_sample.ipynb'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/_db.ipynb'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/_spark.ipynb'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/example2.parquet'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/download_sample'),
#  PosixPath('/home/kimlab2/database_data/datapkg/pmc_tables/notebooks/1088961.xml'),
# ...

# %%
xml_files
# Out:
# ['gb-2005-6-4-r33-S1.xls', 'gb-2005-6-4-r33-S2.xls']

# %%
extracted_files = []

tmpdir = tempfile.mkdtemp()
#with tempfile.TemporaryDirectory() as tmpdir:
for file in csv_files + xml_files:
    extracted_file = zfile.extract(file, tmpdir)
    extracted_files.append(extracted_file)

# %%
extracted_files
# Out:
# ['/tmp/strokach/tmp8mpdyfn4/gb-2005-6-4-r33-S1.xls',
#  '/tmp/strokach/tmp8mpdyfn4/gb-2005-6-4-r33-S2.xls']

# %%
df = pd.read_excel(extracted_files[0], None)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df.keys()
# Out:
# odict_keys(['Adrenal_gland', 'Amygdala', 'Caudate_nucleus', 'Cerebellum', 'Corpus_callosum', 'Cortex', 'Drg', 'Heart', 'Kidney', 'Liver', 'Lung', 'Ovary', 'Pancreas', 'Pituitary_gland', 'Placenta', 'Prostate', 'Salivary_gland', 'Spinal_cord', 'Spleen', 'Testis', 'Thalamus', 'Thymus', 'Thyroid', 'Trachea', 'Uterus'])

# %%
for key, df in dfs.items():
    df['pmc_id'] = 
    df['file_name'] = file
    df['sheet_name'] = key

# %%
df = pd.DataFrame([['a', 'b', 'c'], ['d', 'e', 'f']], index=[10, 11])
df
# Out:
#     0  1  2
# 10  a  b  c
# 11  d  e  f

# %%
df.rename(columns=df.iloc[0]).drop(df.index[0])
# Out:
#     a  b  c
# 11  d  e  f

# %%
df.columns = df.iloc[0]
df = df[1:]

# %%
df.reindex(columns=df.index.drop(0))
# Out:
#    1
# 0  2
# 1  5

# %%
df.index.drop(0)
# Out:
# Int64Index([1], dtype='int64')

# %%
filename = z1.extract(f.filename, path=tmpdir)

# %%
filename
# Out:
# '/tmp/strokach/tmpvujfij2p/1088961.xml'

# %%
# !head {filename}
# Out:
# <!DOCTYPE article PUBLIC "-//NLM//DTD Journal Archiving and Interchange DTD v2.1 20050630//EN" "archivearticle.dtd">
# ...

# %%
df = pd.read_excel(filename)
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-40-9cb8d1ebe1ea> in <module>()
# ----> 1 df = pd.read_excel(filename)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
# ...
